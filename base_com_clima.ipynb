# %%
import pandas as pd

path_daily = 'bases_tratadas/daily_peak_transformers_dataset.csv'
df_daily = pd.read_csv(path_daily, sep=';', encoding='latin-1')

url_weather = "https://media.githubusercontent.com/media/ruanvirginio/masters/refs/heads/main/bases_tratadas/weather_dataset_2022-2024.csv"
df_weather = pd.read_csv(url_weather,  sep=';', encoding='latin-1')

# %%
df_weather
# Out:
#             DATA  temp_max  temp_min  temp_media  precipitacao_total  dia  \
# 0     2022-01-01      30.0      27.0   28.800000                 0.0    1
# 1     2022-01-02      31.0      31.0   31.000000                 0.0    2
# 2     2022-01-03       NaN       NaN         NaN                 0.0    3
# 3     2022-01-04      31.0      27.0   29.000000                 0.0    4
# 4     2022-01-05      31.0      25.0   28.000000                 4.0    5
# ...          ...       ...       ...         ...                 ...  ...
# 1091  2024-12-27      27.0      25.0   26.000000                 2.0   27
# 1092  2024-12-28       NaN       NaN         NaN                 0.0   28
# 1093  2024-12-29      31.0      26.0   28.200000                 0.0   29
# 1094  2024-12-30      30.0      25.0   27.666667                 0.0   30
# 1095  2024-12-31      26.0      26.0   26.000000                 0.0   31
#
#       mes  temp_max_anos  temp_min_anos  temp_media_anos  precipitacao_anos
# ...
